# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

from sklearn import datasets, tree, metrics
from sklearn.model_selection import train_test_split

student = 'Hồ Thành Đạt - 6351071017'

# %%
digits = datasets.load_digits()

print(student)

_, axes = plt.subplots(1, 4)
images_and_lables = list(zip(digits.images, digits.target))
for ax, (image, lable) in zip(axes, images_and_lables[:4]):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation="nearest")
    ax.set_title("Training: %i" % lable)
plt.show()
# Out:
# Hồ Thành Đạt - 6351071017

# %%
n_samples = len(digits.images)
data = digits.images.reshape((n_samples, -1))

classifier = tree.DecisionTreeClassifier(criterion="entropy", random_state=33)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, digits.target, test_size=0.2, shuffle=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=33)

# %%
predicted = classifier.predict(X_test)

# %%
print(student)
_, axes = plt.subplots(1,4)
images_and_predictions = list(zip(digits.images[n_samples // 2:], predicted))
for ax, (image, prediction) in zip(axes, images_and_predictions[:4]):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation="nearest")
    ax.set_title('Prediction: %i' % prediction)
plt.show()
# Out:
# Hồ Thành Đạt - 6351071017

# %%
print(student)
print("Classification report for classifier %s:\n%s\n"
      % (classifier, metrics.classification_report(y_test, predicted)))
disp = metrics.ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test)
disp.figure_.suptitle("Confusion Matrix")
print("Confusion matrix: \n%s" % disp.confusion_matrix)
# Out:
# Hồ Thành Đạt - 6351071017
# Classification report for classifier DecisionTreeClassifier(criterion='entropy', random_state=33):
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87        35
#            1       0.72      0.64      0.68        36
#            2       0.76      0.74      0.75        35
#            3       0.69      0.59      0.64        37
#            4       0.86      0.84      0.85        37
#            5       0.80      0.95      0.86        37
#            6       0.97      0.95      0.96        37
#            7       0.78      0.86      0.82        36
#            8       0.79      0.82      0.81        33
#            9       0.72      0.70      0.71        37
#
#     accuracy                           0.80       360
#    macro avg       0.80      0.80      0.79       360
# weighted avg       0.80      0.80      0.79       360
#
#
# Confusion matrix:
# [[31  0  0  0  1  0  0  0  1  2]
# ...

# %%
print(student)
from PIL import Image, ImageOps
import numpy as np
import requests
from io import BytesIO

url = 'https://raw.githubusercontent.com/thanhdatho0/6351071017_Lab2/main/Dataset/test_image_Bai7.jpg'
response = requests.get(url)
response.raise_for_status()
img = Image.open(BytesIO(response.content)).convert("L").resize((8,8))

img = ImageOps.invert(img)

im2arr = np.array(img)

plt.imshow(im2arr, cmap=plt.cm.gray_r, interpolation="nearest")
# Out:
# Hồ Thành Đạt - 6351071017

# %%
print(student)

img1d=im2arr.reshape([1,64])

img1d[img1d > 109] = 155
img1d[img1d< 110] = 0
img1d
# Out:
# Hồ Thành Đạt - 6351071017
# array([[  0,   0, 155, 155, 155,   0,   0,   0,   0,   0, 155,   0,   0,
#         155,   0,   0,   0,   0, 155,   0,   0, 155,   0,   0,   0,   0,
#         155,   0, 155, 155,   0,   0,   0,   0,   0,   0, 155,   0,   0,
#           0,   0,   0,   0, 155,   0,   0,   0,   0,   0,   0, 155, 155,
#           0, 155,   0,   0,   0,   0, 155, 155, 155, 155,   0,   0]],
#       dtype=uint8)

# %%
print(student)

plt.imshow(img1d.reshape(8,8), cmap=plt.cm.gray_r, interpolation="nearest")
# Out:
# Hồ Thành Đạt - 6351071017

# %%
print(student)
y_pred = classifier.predict(img1d)
print(y_pred)
# Out:
# Hồ Thành Đạt - 6351071017
# [2]

# %%
url = 'https://raw.githubusercontent.com/thanhdatho0/6351071017_Lab2/main/Dataset/test_image_Bai7(1).jpg'
response = requests.get(url)
response.raise_for_status()
img = Image.open(BytesIO(response.content)).convert("L").resize((8,8))

img = ImageOps.invert(img)

im2arr = np.array(img)

plt.imshow(im2arr, cmap=plt.cm.gray_r, interpolation="nearest")

# %%
print(student)

img1d=im2arr.reshape([1,64])

img1d[img1d > 109] = 155
img1d[img1d< 110] = 0
img1d
# Out:
# Hồ Thành Đạt - 6351071017
# array([[  0,   0,   0,   0, 155,   0,   0,   0,   0,   0,   0,   0, 155,
#           0,   0,   0,   0,   0,   0, 155, 155,   0,   0,   0,   0,   0,
#           0, 155, 155,   0,   0,   0,   0,   0,   0,   0, 155,   0,   0,
#           0,   0,   0,   0,   0, 155,   0,   0,   0,   0,   0,   0,   0,
#         155,   0,   0,   0,   0,   0,   0, 155, 155,   0,   0,   0]],
#       dtype=uint8)

# %%
print(student)

plt.imshow(img1d.reshape(8,8), cmap=plt.cm.gray_r, interpolation="nearest")
# Out:
# Hồ Thành Đạt - 6351071017

# %%
print(student)
y_pred = classifier.predict(img1d)
print(y_pred)
# Out:
# Hồ Thành Đạt - 6351071017
# [1]
